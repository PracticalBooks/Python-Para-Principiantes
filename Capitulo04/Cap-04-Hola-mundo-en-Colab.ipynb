# %% [markdown]
# **Nuestro primer código – Hola mundo**

# %%
print("hola mundo")

# %% [markdown]
# **Múltiples Hola Mundo**

# %%
print("hola mundo")
print("hola mundo")
print("hola mundo")

# %% [markdown]
# **Imprimiendo la versión de Python**

# %%
# !python --version
